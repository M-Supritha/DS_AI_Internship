# %%
# Day21_Intro_to_ML.py

"""
Machine Learning is a way of teaching computers to learn patterns from data instead of
explicitly programming every rule. In traditional programming, we give the computer
data and clear instructions to produce results. But in Machine Learning, we provide
the computer with data and correct answers, and it automatically discovers the rules
or patterns needed to make predictions. This allows systems to improve their
performance as they are exposed to more data.
"""

print("Day 21 - Introduction to Machine Learning")
print("\nExplanation:")
print("Machine Learning is a way of teaching computers to learn patterns from data instead of explicitly programming every rule. In traditional programming, we give the computer data and clear instructions to produce results. But in Machine Learning, we provide the computer with data and correct answers, and it automatically discovers the rules or patterns needed to make predictions. This allows systems to improve their performance as they are exposed to more data.")
# Out:
# Day 21 - Introduction to Machine Learning
#
# Explanation:
# Machine Learning is a way of teaching computers to learn patterns from data instead of explicitly programming every rule. In traditional programming, we give the computer data and clear instructions to produce results. But in Machine Learning, we provide the computer with data and correct answers, and it automatically discovers the rules or patterns needed to make predictions. This allows systems to improve their performance as they are exposed to more data.
